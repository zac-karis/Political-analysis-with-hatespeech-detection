# %% [markdown]
# # Create a machine learning model that will correctly identify politician names and political parties

# %%
import spacy
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from spacy.language import Language

import json
import re

import preprocessor as p
import string
import langdetect
import nltk

import pandas as pd

import requests
from bs4 import BeautifulSoup as bs
import html5lib

## Get data from pdf
import pdfplumber

# %%
uhuru_refs = [
    "Uhuru Muigai Kenyatta",
    "Number one",
    "Uhunye",
    "Jayden"
]
raila_refs = [
    "Raila Amolo Odinga",
    "Baba",
    "Rao",
    "Kitendawili",
    
    ]
ruto_refs =[
    "William Samoei Ruto",
    "Willie",
    "Deputy President",
    "DP",
    "Wheelbarrow",
    "Bwana Mashamba",
    "WSR"
]
other_politicians = [
    "Kalonzo Musyoka",
    "Musalia Mudavadi",
    "William Kabogo",
    "Moses Wetangula",
    "Jamali Gaddafi",
    "Roy Smith Mwatia Rufftone",
    "Felix Odiwour Jalango",
    "Jasper Muthomi",
    "MC Jessy",
    "Tabitha Karanja",
    "Anita Soina",
    "Jackson Makini Prezzo",
    "Alex Mwakideu",
    "Tony Kwalanda",
    "Davidson Ngibuini DNG"
    "Mohammed Ali"
    "Johnson Sakaja",
    "Kimani Wamatangi",
    "Irungu Kangata",
    "James Orengo",
    "Susan Kihika",
    "Ledama Olekina",
    "Charles Kibiru",
    "Cleophas Malala",
    "George Khaniri",
    "Mithika Linturi",
    "Mutula Kilonzo Jnr",
    "Kithure Kindiki",
    "Mohamed Mahamud",
    "Sam Ongeri",
    "Fred Outa",
    "Ochillo Ayacko",
    "Steward Madzayo",
    "Margaret Kamar",
    "Kipchumba Murkomen",
    "Okong’o Omogeni",
    "Johnson Sakaja",
    "Anyang Nyong’o",
    "Alfred Mutua",
    "Evans Kidero"
]

# %%
political_parties = [
    "ODM",
    "Azimio la Umoja",
    "UDA",
    "Farmers Party",
    "Orange Democratic Movement",
    "Wiper",
    "NARC Kenya",
    "Chama Cha Kazi",
    "Tujibebe Wakenya",
    "Amani National Congress",
    "Ford Kenya",
    "Azimio",
    "Ford"
]

# %% [markdown]
# ## Get more names and politcal parties from pdf file

# %% [markdown]
# ### Senate members and parties

# %%
def get_names_from_pdf(file):
    pdf = pdfplumber.open(file)
    no_of_pages = len(pdf.pages)
    data = []
    for i in range(no_of_pages):
        page = pdf.pages[i]
        table = page.extract_table()
        for row in table:
            name = row[1]
            if name != "Name":
                # clean the name 
                name = name.split("Sen.")[1].split(",")[0]
                data.append(name)
    return data

# %%
def get_political_parties_from_pdf(file):
    pdf = pdfplumber.open(file)
    no_of_pages = len(pdf.pages)
    data = []
    for i in range(no_of_pages):
        page = pdf.pages[i]
        table = page.extract_table()
        for row in table:
            party = row[-1]
            if party != "Political Party":
                data.append(party)
    return data

# %% [markdown]
# ### Get from National Government File

# %%
def get_names_from_pdf_NA(file):
    pdf = pdfplumber.open(file)
    no_of_pages = len(pdf.pages)
    data = []
    for i in range(14):
        page = pdf.pages[i]
        table = page.extract_table()
        for row in table:
            name = row[1]
            if name != "NAME":
                if name == "" or name == None:
                    name = row[2]
                if name != "" and name != None:
                    data.append(name)
    return data

# %%
def get_parties_from_pdf_NA(file):
    pdf = pdfplumber.open(file)
    data = []
    page = pdf.pages[14]
    table = page.extract_table()
    for row in table:
        name = row[0]
        if name != "PARTY NAME":
            data.append(name)
            
        name = row[1]
        if name != "PARTY \nABBREVIATION":
            data.append(name)
    return data

# %% [markdown]
# ### Get from url containing registered political parties

# %% [markdown]
# ### Code used to get the table for the political parties
#
# page = requests.get("https://victormatara.com/list-of-all-registered-political-parties-in-kenya-2018/")
#
# df_list = pd.read_html(page.text) # this parses all the tables in webpages to a list
#
# df = df_list[0]
#
# df.to_csv("parties.csv")

# %%
def get_registered_parties(file):
    data = []
    df = pd.read_csv(file)
    names = df["PARTY NAME"].tolist()
    abbreviations = df["ABBREV"].tolist()
    
    for name in names:
        data.append(name)
        
    for abb in abbreviations:
        data.append(abb)
    return data

# %%
#parties from the senate file
senate_parties = get_political_parties_from_pdf("LIST OF SENATE DELEGATIONS AND POLITICAL PARTIES.pdf")
for party in senate_parties:
    political_parties.append(party)
    
#parties from the national_assembly
parties_NA = get_parties_from_pdf_NA("LIST OF MEMBERS OF NA BY PARTY - 25012022.pdf")
parties_NA
for party in parties_NA:
    political_parties.append(party)
    
#parties from registered parties url
registered_parties = get_registered_parties("parties.csv")
for party in registered_parties:
    political_parties.append(party)

political_parties= list(set(political_parties))

# %%
#get names from the senate file
senate_names = get_names_from_pdf("LIST OF SENATE DELEGATIONS AND POLITICAL PARTIES.pdf")
for name in senate_names:
    other_politicians.append(name)
    
#get parties from the national assembly file
national_assembly_names = get_names_from_pdf_NA("LIST OF MEMBERS OF NA BY PARTY - 25012022.pdf")
for name in national_assembly_names:
    other_politicians.append(name)
    
other_politicians = list(set(other_politicians))

# %% [markdown]
# ## Create more names and references for better detection

# %%
stopwords = nltk.corpus.stopwords.words("english")
other_stopwords=["one", "President", "MC", "Kenya", "party", "-", "_", "Democratic", "Chama", "National", "la", "Amani, Umoja,", "These", "Confidant"]
for stop in other_stopwords:
    stopwords.append(stop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16248/179540655.py in <module>
# ----> 1 stopwords = nltk.corpus.stopwords.words("english")
#       2 other_stopwords=["one", "President", "MC", "Kenya", "party", "-", "_", "Democratic", "Chama", "National", "la", "Amani, Umoja,", "These", "Confidant"]
#       3 for stop in other_stopwords:
#       4     stopwords.append(stop)
#
# NameError: name 'nltk' is not defined

# %%
def generate_better_names(refs):
    new_characters = []
    
    #first add the complete names
    for r in refs:
        new_characters.append(r)
        
    #print(len(new_characters))
    #split the names into indvidual names
    for r in refs:
        names = r.split()
        for name in names:
            name = name.strip()
            if name not in stopwords:
                new_characters.append(name)
    #print(len(new_characters))

    titles = ["Dr.", "Professor", "Mr.", "Mrs.", "Ms.", "Miss", "Aunt", "Uncle", "Mr. and Mrs."]
    final_characters = []
    for char in new_characters:
        if char !="":
            final_characters.append(char)
        for title in titles:
            titled_char = f"{title} {char}"
            final_characters.append(titled_char)
    #print(len(final_characters))            
    return final_characters

# %%
ruto_fnl_refs = generate_better_names(ruto_refs)
uhuru_fnl_refs= generate_better_names(uhuru_refs)
raila_fnl_refs = generate_better_names(raila_refs)
other_politicians_refs = generate_better_names(other_politicians)

# %% [markdown]
# ## Create training data

# %%
def create_training_data(refs, type):
    data = generate_better_names(refs)
    patterns = []
    
    for item in data:
        pattern = {
            "label": type,
            "pattern": item
        }
        patterns.append(pattern)
        
    return patterns

# %%
uhuru_patterns = create_training_data(uhuru_fnl_refs, "POLITICIAN")
ruto_patterns = create_training_data(ruto_fnl_refs, "POLITICIAN")
raila_patterns = create_training_data(raila_fnl_refs, "POLITICIAN")
other_politicians_patterns = create_training_data(other_politicians_refs, "POLITICIAN")
poltical_parties_patters = create_training_data(political_parties, "POLITICAL_PARTY")

# %%
patterns = [uhuru_patterns, ruto_patterns, raila_patterns, other_politicians_patterns, poltical_parties_patters]

# %%
def generate_rules(patterns):
    nlp = English()
    ruler = EntityRuler(nlp)
    ruler = nlp.add_pipe('entity_ruler')
    for pattern in patterns:
        ruler.add_patterns(pattern)
    nlp.to_disk("political_ner")

# %%
generate_rules(patterns)

# %% [markdown]
# ## Test the model

# %%
df1 = pd.read_csv("data/facebook12.csv")
df2 = pd.read_csv("data/facebook_6.csv")
df3= pd.read_csv("data/facebook4.csv")
df4= pd.read_csv("data/facebook2.csv")
df5= pd.read_csv("data/facebook9.csv")
df6= pd.read_csv("data/facebook10.csv")
df7= pd.read_csv("data/facebook16.csv")
df8= pd.read_csv("data/facebook17.csv")
df9= pd.read_csv("data/facebook18.csv")
df10= pd.read_csv("data/facebook19.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], axis=0)
df.reset_index()
# Out:
#       index                    Username  \
# 0         0              Mulei Ule Msee
# 1         1                Daniel David
# 2         2  Ngiroh Christopher Kipsang
# 3         3       Humfred Kabasa Junior
# 4         4                    Den Nish
# ...     ...                         ...
# 2781    332              Brayoo Wiseman
# 2782    333              Njeri Anjeline
# 2783    334                William Ouma
# 2784    335                 Zipsy Ndush
# 2785    336                 Zipsy Ndush
#
#                                                 comment
# 0                            What will happen to kidero
# 1     If only God could hear my prayer then Magwanga...
# 2     Then you will hear him pointing fingers at Rut...
# 3     The so called ODM is doing more harm than good...
# 4     Chinua Achebe says " a goat is not left to suf...
# ...                                                 ...
# 2781                                   Ruto is confused
# 2782                                Stop that nonsense.
# 2783  So Raila wanted to impeach Uhuru so that Ruto ...
# 2784          Philemon Liech kumbe unaenda muchene hivo
# 2785     Philemon Liech Hii haitatufanya tuingie Azimio
#
# [2786 rows x 3 columns]

# %% [markdown]
# ## Clean text

# %%
# regular expression to remove additional punctuation marks and other meta data such as breaks
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\|)|(\()|(\))|(\[)|(\])|(\%)|(\$)|(\>)|(\<)|(\{)|(\})")
REPLACE_WITH_SPACE = re.compile("(<br\s/><br\s/?)|(-)|(/)|(:).")
def tweet_processing(line):
    # empty list to hold cleaned tweets
        # clean using tweet preprocessor
    clean = p.clean(line)
    # remove punctuations
    text  = "".join([char for char in clean if char not in string.punctuation])
    text = re.sub('[0-9]+', '', text)
    text = REPLACE_NO_SPACE.sub("", text)
    text = REPLACE_WITH_SPACE.sub(" ", text)
    return text


#run the method
df['clean_comments'] = df['comment'].apply(lambda x: tweet_processing(x))

# %%
nlp = spacy.load("political_ner")

# %%
df["tags"] = df["comment"].apply(lambda x: [(tag.text, tag.label_) for tag in nlp(x).ents])

# %%
df[1:50]
# Out:
#                       Username  \
# 1                 Daniel David
# 2   Ngiroh Christopher Kipsang
# 3        Humfred Kabasa Junior
# 4                     Den Nish
# 5   Philip Chianda Ja Nyamware
# 6              Richard Njuguna
# 7                   Fred Okeke
# 8                  Vitz Cherui
# 9                 Omiti Otieno
# 10            Crispin Nyakweba
# 11             Nyakwar Jabunde
# 12              Victor Onyango
# 13                  Nick Ocham
# 14                Omiti Otieno
# 15                  Aimo Alpha
# 16                Adhudhu Leah
# 17               Don Owino Jr.
# 18               Oketch Samson
# 19                Ngare Romans
# 20                Julius Agiro
# 21             Kileshi Mondela
# 22             Stephen Kibegwa
# 23  Cheruiyot Kenyalito Kosgey
# 24              Jacob Odhiambo
# 25             Johnson Kimutai
# 26             Justin Onyancha
# 27                   Esy Lasty
# 28                  TJ Misinga
# 29               Michael Ajush
# 30                Ogunah Elvis
# 31                Peter Shisia
# 32               Jsunda Senior
# 33               Marvin Omondi
# 34        Simon Mucheke Waweru
# 35            Robikip Robinson
# 36              Empress Dachez
# 37           Akumu Brian Akumu
# 38               Ojijo Collins
# 39          Rummax Wuo Peninah
# 40          Peter Kosgey Okeyo
# 41         Githinji Wa Kariuki
# 42                     Maurice
# 43                Jacob Riendo
# 44                Raymond Sang
# 45             Viñcent Onyango
# 46               Bonke Komwayi
# 47               Ogona Supremo
# 48                  Kevin Ouma
# 49            Sheltone Cheriot
#
#                                               comment  \
# 1   If only God could hear my prayer then Magwanga...
# 2   Then you will hear him pointing fingers at Rut...
# 3   The so called ODM is doing more harm than good...
# 4   Chinua Achebe says " a goat is not left to suf...
# 5   Those that are belittling Wanga..that lady is ...
# 6   You mean Mr chairman you can't make it to gube...
# 7   The decision and selection will be made in Kar...
# 8   Kidero might not be the popular candidate amon...
# 9   As homabain from Kasipul constituency, I'm goi...
# 10  As a resident of Homabay Asumbi, we would rath...
# 11  This woman will never be homabay gavana, she W...
# 12  Wanga is always leading on social media but as...
# 13  I would be pleased to see the first female Luo...
# 14  That's the reason why I'll not participate in ...
# 15  There are stronger candidates than Mbadi there...
# 16  From a distance Mbadi saw him self loosing the...
# 17  James Orengo and Oburu Oginga should follow su...
# 18            Mbadi was going no where, same to wanga
# 19  We are tired  with  Odingasm in Luo Nyanza. Ra...
# 20      How is it a boost?We want a fair nominations!
# 21  If a whole chairman{cow} chickens out, whats a...
# 22     Wanga will take she has history of performance
# 23  He realised that he wasn't going get adirect t...
# 24  This man Mbadi has no greed for power..it's no...
# 25  Mbadi knew he was going nowhere, even his vill...
# 26             Kidero should seek the seat in Nairobi
# 27  Mbadi's withdrawal is from their father,we kno...
# 28  Wanga all the way the only threat we had was t...
# 29  The race is still stiff than even before mbadi...
# 30             Wanga would win with or without  Mbadi
# 31                Negotiated democracy.......ni upuzi
# 32                        Magwanga is in the race too
# 33  Kama unajua you are not a,voter in Homabay don...
# 34  Mbadi did not drop his bid, he was ordered to ...
# 35  Angenyoroshwa nyoronyoro. The woman's record i...
# 36  Very good coz no one was going to elect him # ...
# 37  Voter apathy loading. If Homabay County reside...
# 38  Mbadi was never a factor in the race. Hon Jose...
# 39  Gladys is the next homabay  governor.. kidero ...
# 40  Why is it a boost for Wanga only? I think have...
# 41                     Kidero to the county to seat 🪑
# 42                               Magwanga all the way
# 43                  He feared humiliation from kidero
# 44               She will not survive kideros slought
# 45                                     Party Politics
# 46                Why Wanga but not other candidates?
# 47  You only got to mention Gladys Wanga kwani is ...
# 48  Are you sponsored by Wanga to post what you ha...
# 49   She still have to beat Kidero for the ODM ticket
#
#                                        clean_comments  \
# 1   If only God could hear my prayer then Magwanga...
# 2   Then you will hear him pointing fingers at Rut...
# 3   The so called ODM is doing more harm than good...
# 4   Chinua Achebe says  a goat is not left to suff...
# 5   Those that are belittling Wangathat lady is a ...
# 6   You mean Mr chairman you cant make it to guber...
# 7   The decision and selection will be made in Kar...
# 8   Kidero might not be the popular candidate amon...
# 9   As homabain from Kasipul constituency Im going...
# 10  As a resident of Homabay Asumbi we would rathe...
# 11  This woman will never be homabay gavana she WI...
# 12  Wanga is always leading on social media but as...
# 13  I would be pleased to see the first female Luo...
# 14  Thats the reason why Ill not participate in ge...
# 15  There are stronger candidates than Mbadi there...
# 16  From a distance Mbadi saw him self loosing the...
# 17  James Orengo and Oburu Oginga should follow su...
# 18             Mbadi was going no where same to wanga
# 19  We are tired with Odingasm in Luo Nyanza Raila...
# 20        How is it a boostWe want a fair nominations
# 21  If a whole chairmancow chickens out whats abou...
# 22     Wanga will take she has history of performance
# 23  He realised that he wasnt going get adirect ti...
# 24  This man Mbadi has no greed for powerits not a...
# 25  Mbadi knew he was going nowhere even his villa...
# 26             Kidero should seek the seat in Nairobi
# 27  Mbadis withdrawal is from their fatherwe know ...
# 28  Wanga all the way the only threat we had was t...
# 29  The race is still stiff than even before mbadi...
# 30              Wanga would win with or without Mbadi
# 31                       Negotiated democracyni upuzi
# 32                        Magwanga is in the race too
# 33  Kama unajua you are not avoter in Homabay dont...
# 34  Mbadi did not drop his bid he was ordered to w...
# 35  Angenyoroshwa nyoronyoro The womans record is ...
# 36  Very good coz no one was going to elect him ge...
# 37  Voter apathy loading If Homabay County residen...
# 38  Mbadi was never a factor in the race Hon Josep...
# 39  Gladys is the next homabay governor kidero wil...
# 40  Why is it a boost for Wanga only I think have ...
# 41                       Kidero to the county to seat
# 42                               Magwanga all the way
# 43                  He feared humiliation from kidero
# 44               She will not survive kideros slought
# 45                                     Party Politics
# 46                 Why Wanga but not other candidates
# 47  You only got to mention Gladys Wanga kwani is ...
# 48  Are you sponsored by Wanga to post what you ha...
# 49   She still have to beat Kidero for the ODM ticket
#
#                                                  tags
# 1                                                  []
# 2                               [(Raila, POLITICIAN)]
# 3    [(ODM, POLITICAL_PARTY), (ODM, POLITICAL_PARTY)]
# 4                             [(OF, POLITICAL_PARTY)]
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8          [(Kidero, POLITICIAN), (Baba, POLITICIAN)]
# 9   [(William, POLITICIAN), (Ruto, POLITICIAN), (R...
# 10                           [(ODM, POLITICAL_PARTY)]
# 11                             [(Odinga, POLITICIAN)]
# 12                                                 []
# 13                                                 []
# 14                               [(Ruto, POLITICIAN)]
# 15        [(Mbadi, POLITICIAN), (Kidero, POLITICIAN)]
# 16                              [(Mbadi, POLITICIAN)]
# 17                       [(James Orengo, POLITICIAN)]
# 18                              [(Mbadi, POLITICIAN)]
# 19                              [(Raila, POLITICIAN)]
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                              [(Mbadi, POLITICIAN)]
# 25                              [(Mbadi, POLITICIAN)]
# 26                             [(Kidero, POLITICIAN)]
# 27                              [(Mbadi, POLITICIAN)]
# 28       [(ODM, POLITICAL_PARTY), (John, POLITICIAN)]
# 29                                                 []
# 30                              [(Mbadi, POLITICIAN)]
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                              [(Mbadi, POLITICIAN)]
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38        [(Mbadi, POLITICIAN), (Joseph, POLITICIAN)]
# 39                             [(Gladys, POLITICIAN)]
# 40                                                 []
# 41                             [(Kidero, POLITICIAN)]
# 42                                                 []
# 43                                                 []
# 44                                                 []
# 45                         [(Party, POLITICAL_PARTY)]
# 46                                                 []
# 47                             [(Gladys, POLITICIAN)]
# 48                                                 []
# 49     [(Kidero, POLITICIAN), (ODM, POLITICAL_PARTY)]

# %%
tags = df["tags"].to_list()
len(tags)
# Out:
# 2786

# %%
tags = list(filter(None, tags))

# %%
len(tags)
# Out:
# 916

# %% [markdown]
# # CREATE TRAINING DATA

# %%
def save_data(file, data):
    with open(file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent = 4)

# %%
def test_model(model, text):
    doc = nlp(text)
    results =[]
    entities = []
    
    for ent in doc.ents:
        entities.append((ent.start_char, ent.end_char, ent.label_))
        
    if len(entities) >0:
        results = [text, {"entities": entities}]
        return results

# %%
nlp = spacy.load("political_ner")

# %%
TRAIN_DATA = []
all_comments = df["comment"].to_list()

for comment in all_comments:
    #clean the comments
    comment = p.clean(comment).strip()
    results = test_model(nlp, comment)
    
    # include only entities that have found a result
    if results != None:
        TRAIN_DATA.append(results)

# %%
len(TRAIN_DATA)
# Out:
# 915

# %%
save_data("data/political_training_data.json", TRAIN_DATA)
